# %%
import quandl

# %%
quandl.ApiConfig.api_key = '{yourkeyhere}'

# %%
data = quandl.get("TFGRAIN/SOYBEANS", authtoken="{yourkeyhere}")

# %%
data.tail()
# Out:
#             Cash Price  Basis  Fall Price  Fall Basis
# Date
# 2019-01-08        8.56  -0.63        9.13       -0.45
# 2019-01-09        8.61  -0.63        9.18       -0.45
# 2019-01-10        8.45  -0.62        9.03       -0.45
# 2019-01-11        8.48  -0.62        9.07       -0.45
# 2019-01-14        8.42  -0.62        9.02       -0.45

# %%
len(data)
# Out:
# 4535

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from fastai.imports import *
from fastai.structured import *
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display
from sklearn import metrics

# %%
data.rename_axis('Date')
# Out:
#             Cash Price  Basis  Fall Price  Fall Basis
# Date
# 2000-12-01        4.90  -0.18        5.02       -0.26
# 2000-12-04        4.87  -0.18        4.99       -0.26
# 2000-12-05        4.83  -0.18        4.98       -0.26
# 2000-12-06        4.89  -0.18        5.02       -0.26
# 2000-12-07        4.85  -0.18        4.98       -0.26
# 2000-12-08        4.94  -0.18        5.03       -0.26
# 2000-12-11        4.93  -0.18        5.00       -0.26
# 2000-12-12        4.89  -0.19        4.96       -0.26
# 2000-12-13        4.88  -0.19        4.97       -0.26
# 2000-12-14        4.86  -0.19        4.97       -0.26
# 2000-12-15        4.89  -0.19        4.99       -0.26
# 2000-12-18        4.91  -0.19        5.02       -0.26
# 2000-12-19        4.93  -0.19        5.03       -0.26
# 2000-12-20        4.91  -0.17        5.00       -0.26
# 2000-12-21        4.95  -0.15        5.01       -0.26
# 2000-12-22        4.96  -0.15        4.98       -0.26
# ...

# %%
data['Date'] = data.index
add_datepart(data, 'Date')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4535 entries, 2000-12-01 to 2019-01-14
# Data columns (total 18 columns):
# id                  4535 non-null int64
# Cash Price          4535 non-null float64
# Basis               4535 non-null float64
# Fall Price          4516 non-null float64
# Fall Basis          4516 non-null float64
# Year                4535 non-null int64
# Month               4535 non-null int64
# Week                4535 non-null int64
# Day                 4535 non-null int64
# Dayofweek           4535 non-null int64
# Dayofyear           4535 non-null int64
# Is_month_end        4535 non-null bool
# Is_month_start      4535 non-null bool
# Is_quarter_end      4535 non-null bool
# Is_quarter_start    4535 non-null bool
# Is_year_end         4535 non-null bool
# Is_year_start       4535 non-null bool
# Elapsed             4535 non-null int64
# dtypes: bool(6), float64(4), int64(8)
# memory usage: 487.2 KB

# %%
##not working, see inelegant below
dfdata = data.reset_index()
dfdata.columns[0] = 'Id'
dfdata['Id'] = dfdata.index
dfdata.info()
#dfdata = data
#dfdata.insert(0,'id', range(0,len(dfdata)))
#dfdata.set_index('id')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-955f309c8341> in <module>
#       1 dfdata = data.reset_index()
# ----> 2 dfdata.columns[0] = 'Id'
#       3 dfdata['Id'] = dfdata.index
#       4 dfdata.info()
#       5 #dfdata = data
#
# ~/anaconda3/envs/fastai-cpu/lib/python3.6/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    2063
#    2064     def __setitem__(self, key, value):
# -> 2065         raise TypeError("Index does not support mutable operations")
#    2066
#    2067     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
col_list = ['Cash Price', 'Basis', 'Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear']
dfdata = dfdata[col_list]

# %%
npdf = dfdata.values

# %%
npdf
# Out:
# array([[   4.9 ,   -0.18, 2000.  , ...,    1.  ,    4.  ,  336.  ],
#        [   4.87,   -0.18, 2000.  , ...,    4.  ,    0.  ,  339.  ],
#        [   4.83,   -0.18, 2000.  , ...,    5.  ,    1.  ,  340.  ],
#        ...,
#        [   8.45,   -0.62, 2019.  , ...,   10.  ,    3.  ,   10.  ],
#        [   8.48,   -0.62, 2019.  , ...,   11.  ,    4.  ,   11.  ],
#        [   8.42,   -0.62, 2019.  , ...,   14.  ,    0.  ,   14.  ]])

# %%
fnpdf = pd.DataFrame.from_records(npdf)

# %%
fnpdf
# Out:
#          0     1       2     3     4     5    6      7
# 0     4.90 -0.18  2000.0  12.0  48.0   1.0  4.0  336.0
# 1     4.87 -0.18  2000.0  12.0  49.0   4.0  0.0  339.0
# 2     4.83 -0.18  2000.0  12.0  49.0   5.0  1.0  340.0
# 3     4.89 -0.18  2000.0  12.0  49.0   6.0  2.0  341.0
# 4     4.85 -0.18  2000.0  12.0  49.0   7.0  3.0  342.0
# 5     4.94 -0.18  2000.0  12.0  49.0   8.0  4.0  343.0
# 6     4.93 -0.18  2000.0  12.0  50.0  11.0  0.0  346.0
# 7     4.89 -0.19  2000.0  12.0  50.0  12.0  1.0  347.0
# 8     4.88 -0.19  2000.0  12.0  50.0  13.0  2.0  348.0
# 9     4.86 -0.19  2000.0  12.0  50.0  14.0  3.0  349.0
# 10    4.89 -0.19  2000.0  12.0  50.0  15.0  4.0  350.0
# 11    4.91 -0.19  2000.0  12.0  51.0  18.0  0.0  353.0
# 12    4.93 -0.19  2000.0  12.0  51.0  19.0  1.0  354.0
# 13    4.91 -0.17  2000.0  12.0  51.0  20.0  2.0  355.0
# 14    4.95 -0.15  2000.0  12.0  51.0  21.0  3.0  356.0
# 15    4.96 -0.15  2000.0  12.0  51.0  22.0  4.0  357.0
# ...

# %%
#fnpdf.drop([10], inplace=True, axis=1)

# %%
fnpdf.head()
# Out:
#       0     1       2     3     4    5    6      7
# 0  4.90 -0.18  2000.0  12.0  48.0  1.0  4.0  336.0
# 1  4.87 -0.18  2000.0  12.0  49.0  4.0  0.0  339.0
# 2  4.83 -0.18  2000.0  12.0  49.0  5.0  1.0  340.0
# 3  4.89 -0.18  2000.0  12.0  49.0  6.0  2.0  341.0
# 4  4.85 -0.18  2000.0  12.0  49.0  7.0  3.0  342.0

# %%
fnpdf.columns = col_list
fnpdf
# Out:
#       Cash Price  Basis    Year  Month  Week   Day  Dayofweek  Dayofyear
# 0           4.90  -0.18  2000.0   12.0  48.0   1.0        4.0      336.0
# 1           4.87  -0.18  2000.0   12.0  49.0   4.0        0.0      339.0
# 2           4.83  -0.18  2000.0   12.0  49.0   5.0        1.0      340.0
# 3           4.89  -0.18  2000.0   12.0  49.0   6.0        2.0      341.0
# 4           4.85  -0.18  2000.0   12.0  49.0   7.0        3.0      342.0
# 5           4.94  -0.18  2000.0   12.0  49.0   8.0        4.0      343.0
# 6           4.93  -0.18  2000.0   12.0  50.0  11.0        0.0      346.0
# 7           4.89  -0.19  2000.0   12.0  50.0  12.0        1.0      347.0
# 8           4.88  -0.19  2000.0   12.0  50.0  13.0        2.0      348.0
# 9           4.86  -0.19  2000.0   12.0  50.0  14.0        3.0      349.0
# 10          4.89  -0.19  2000.0   12.0  50.0  15.0        4.0      350.0
# 11          4.91  -0.19  2000.0   12.0  51.0  18.0        0.0      353.0
# ...

# %%
train_cats(fnpdf)

# %%
df, y, nas = proc_df(fnpdf, 'Cash Price')

# %%
df
# Out:
#       Basis    Year  Month  Week   Day  Dayofweek  Dayofyear
# 0     -0.18  2000.0   12.0  48.0   1.0        4.0      336.0
# 1     -0.18  2000.0   12.0  49.0   4.0        0.0      339.0
# 2     -0.18  2000.0   12.0  49.0   5.0        1.0      340.0
# 3     -0.18  2000.0   12.0  49.0   6.0        2.0      341.0
# 4     -0.18  2000.0   12.0  49.0   7.0        3.0      342.0
# 5     -0.18  2000.0   12.0  49.0   8.0        4.0      343.0
# 6     -0.18  2000.0   12.0  50.0  11.0        0.0      346.0
# 7     -0.19  2000.0   12.0  50.0  12.0        1.0      347.0
# 8     -0.19  2000.0   12.0  50.0  13.0        2.0      348.0
# 9     -0.19  2000.0   12.0  50.0  14.0        3.0      349.0
# 10    -0.19  2000.0   12.0  50.0  15.0        4.0      350.0
# 11    -0.19  2000.0   12.0  51.0  18.0        0.0      353.0
# 12    -0.19  2000.0   12.0  51.0  19.0        1.0      354.0
# 13    -0.17  2000.0   12.0  51.0  20.0        2.0      355.0
# ...

# %%
m = RandomForestRegressor(n_jobs=-1)
m.fit(df, y)
m.score(df,y)
# Out:
# /Users/matthew.arthur/anaconda3/envs/fastai-cpu/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9991621993655437

# %%
df.head(1)
# Out:
#    Basis    Year  Month  Week  Day  Dayofweek  Dayofyear
# 0  -0.18  2000.0   12.0  48.0  1.0        4.0      336.0

# %%
df1 = pd.DataFrame({'Basis':[-.75],
                    'Year':[2019],
                    'Month':[1],
                    'Week':[3],
                    'Day':[16],
                    'Dayofweek':[4],
                    'Dayofyear':[16],})
df1
# Out:
#    Basis  Year  Month  Week  Day  Dayofweek  Dayofyear
# 0  -0.75  2019      1     3   16          4         16

# %%
train_cats(df1)

# %%
m.predict(df1)
# Out:
# array([8.465])

# %% [markdown]
# Today's soybean cash price is 8.21 at Pilot Grove versus predicted value of 8.465.
